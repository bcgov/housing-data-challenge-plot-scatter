# %%
# Clears workspace
# %reset -f

# import packages
import pandas as pd
import numpy as np
import json
from pprint import pprint


# set maximum number of rows and columns displayed
pd.set_option('display.max_columns', 12)
pd.set_option('display.max_rows', 10)

# Specifies file to load into dataframe;primary pandas data structure   
df = pd.read_csv('Dwellings_DisArea.csv')

# %%
df
# Out:
#       Geographic code Province / territory, english  \
# 0            59010123              British Columbia
# 1            59010124              British Columbia
# 2            59010125              British Columbia
# 3            59010126              British Columbia
# 4            59010127              British Columbia
# ...               ...                           ...
# 7612         59590023              British Columbia
# 7613         59590024              British Columbia
# 7614         59590025              British Columbia
# 7615         59590026              British Columbia
# 7616         59590027              British Columbia
#
#      Province / territory, french  Geographic code, Province / territory  \
# 0            Colombie-Britannique                                     59
# 1            Colombie-Britannique                                     59
# 2            Colombie-Britannique                                     59
# ...

# %%
df.to_json('Dwellings_DisArea_2016.json')
