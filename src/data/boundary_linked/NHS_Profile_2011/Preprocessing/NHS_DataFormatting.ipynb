# %%
# Clears workspace
# %reset -f

# import packages
import pandas as pd
import numpy as np
import json
from pprint import pprint
import csv

# %%
# set maximum number of rows and columns displayed
pd.set_option('display.max_columns', 12)
pd.set_option('display.max_rows', 5)

# Specifies file to load into dataframe;primary pandas data structure   
df = pd.read_csv('Complete_Municipalities.csv')
df.head()
# Out:
#    Geo_Code         Prov_Name        CD_Name CSD_Name               CSD_type  \
# 0   5901003  British Columbia  East Kootenay  Elkford  District municipality
# 1   5901003  British Columbia  East Kootenay  Elkford  District municipality
# 2   5901003  British Columbia  East Kootenay  Elkford  District municipality
# 3   5901003  British Columbia  East Kootenay  Elkford  District municipality
# 4   5901003  British Columbia  East Kootenay  Elkford  District municipality
#
#     GNR        Topic                                     Characteristic  Note  \
# 0  49.0  Citizenship  Total population in private households by citi...   1.0
# 1  49.0  Citizenship                                  Canadian citizens   NaN
# 2  49.0  Citizenship                    Canadian citizens aged under 18   NaN
# 3  49.0  Citizenship                 Canadian citizens aged 18 and over   NaN
# 4  49.0  Citizenship                              Not Canadian citizens   2.0
#
#   Total  Male Female
# 0  2520  1325   1195
# 1  2400  1280   1120
# 2   570   275    295
# 3  1825  1000    825
# 4   125    45     75

# %%
def sortbytopic(df, topics):
    '''Group dataframe by array of topics and return
    
    df - raw dataframe
    topics - list of topic names
    '''
    
    df_temp = []
    
    for i in range(len(topics)):
        df_temp.append(df.loc[df['Topic']==topics[i]])
    
    return pd.concat(df_temp).reset_index(drop=True)

topics = ['Mobility']
x = sortbytopic(df,topics)
pd.set_option('display.max_rows', 5)
x
# Out:
#       Geo_Code         Prov_Name           CD_Name         CSD_Name  \
# 0      5901003  British Columbia     East Kootenay          Elkford
# 1      5901003  British Columbia     East Kootenay          Elkford
# ...        ...               ...               ...              ...
# 7864   5959810  British Columbia  Northern Rockies  Prophet River 4
# 7865   5959810  British Columbia  Northern Rockies  Prophet River 4
#
#                    CSD_type   GNR     Topic  \
# 0     District municipality  49.0  Mobility
# 1     District municipality  49.0  Mobility
# ...                     ...   ...       ...
# 7864         Indian reserve  11.3  Mobility
# 7865         Indian reserve  11.3  Mobility
#
#                           Characteristic  Note Total  Male Female
# 0     Total - Mobility status 1 year ago  68.0  2495  1310   1190
# 1                             Non-movers   NaN  2200  1150   1045
# ...                                  ...   ...   ...   ...    ...
# 7864            Interprovincial migrants   NaN    10    10      0
# 7865                   External migrants   NaN     0     0      0
#
# [7866 rows x 12 columns]

# %%
df_pivot = pd.pivot_table(x, values='Total', index=['Geo_Code', 'Prov_Name', 'CD_Name', 'CSD_Name'], columns='Characteristic', aggfunc='first')
df_pivot
# Out:
# Characteristic                                                     Interprovincial migrants  \
# Geo_Code Prov_Name        CD_Name          CSD_Name
# 5901003  British Columbia East Kootenay    Elkford                                       95
# 5901006  British Columbia East Kootenay    Sparwood                                     125
# ...                                                                                     ...
# 5959806  British Columbia Northern Rockies Fort Nelson 2                                  0
# 5959810  British Columbia Northern Rockies Prophet River 4                                0
#
# Characteristic                                                     Intraprovincial migrants  \
# Geo_Code Prov_Name        CD_Name          CSD_Name
# 5901003  British Columbia East Kootenay    Elkford                                       85
# 5901006  British Columbia East Kootenay    Sparwood                                     190
# ...                                                                                     ...
# 5959806  British Columbia Northern Rockies Fort Nelson 2                                 15
# 5959810  British Columbia Northern Rockies Prophet River 4                               10
#
# Characteristic                                                   External migrants  \
# Geo_Code Prov_Name        CD_Name          CSD_Name
# 5901003  British Columbia East Kootenay    Elkford                              35
# 5901006  British Columbia East Kootenay    Sparwood                              0
# ...                                                                            ...
# 5959806  British Columbia Northern Rockies Fort Nelson 2                         0
# 5959810  British Columbia Northern Rockies Prophet River 4                       0
#
# Characteristic                                                   Internal migrants  \
# Geo_Code Prov_Name        CD_Name          CSD_Name
# 5901003  British Columbia East Kootenay    Elkford                             175
# 5901006  British Columbia East Kootenay    Sparwood                            310
# ...                                                                            ...
# 5959806  British Columbia Northern Rockies Fort Nelson 2                        20
# 5959810  British Columbia Northern Rockies Prophet River 4                      10
#
# Characteristic                                                 Migrants  \
# Geo_Code Prov_Name        CD_Name          CSD_Name
# 5901003  British Columbia East Kootenay    Elkford                  210
# 5901006  British Columbia East Kootenay    Sparwood                 315
# ...                                                                 ...
# 5959806  British Columbia Northern Rockies Fort Nelson 2             20
# 5959810  British Columbia Northern Rockies Prophet River 4           10
#
# Characteristic                                                 Non-migrants  \
# Geo_Code Prov_Name        CD_Name          CSD_Name
# 5901003  British Columbia East Kootenay    Elkford                       85
# 5901006  British Columbia East Kootenay    Sparwood                     275
# ...                                                                     ...
# 5959806  British Columbia Northern Rockies Fort Nelson 2                 10
# 5959810  British Columbia Northern Rockies Prophet River 4                0
#
# Characteristic                                               Movers  \
# Geo_Code Prov_Name        CD_Name          CSD_Name
# 5901003  British Columbia East Kootenay    Elkford              300
# 5901006  British Columbia East Kootenay    Sparwood             585
# ...                                                             ...
# 5959806  British Columbia Northern Rockies Fort Nelson 2         30
# 5959810  British Columbia Northern Rockies Prophet River 4       10
#
# Characteristic                                               Non-movers  \
# Geo_Code Prov_Name        CD_Name          CSD_Name
# 5901003  British Columbia East Kootenay    Elkford                 2200
# 5901006  British Columbia East Kootenay    Sparwood                3035
# ...                                                                 ...
# 5959806  British Columbia Northern Rockies Fort Nelson 2            410
# 5959810  British Columbia Northern Rockies Prophet River 4          120
#
# Characteristic                                             Total - Mobility status 1 year ago  \
# Geo_Code Prov_Name        CD_Name          CSD_Name
# 5901003  British Columbia East Kootenay    Elkford                                       2495
# 5901006  British Columbia East Kootenay    Sparwood                                      3625
# ...                                                                                       ...
# 5959806  British Columbia Northern Rockies Fort Nelson 2                                  435
# 5959810  British Columbia Northern Rockies Prophet River 4                                125
#
# Characteristic                                             Total - Mobility status 5 years ago
# Geo_Code Prov_Name        CD_Name          CSD_Name
# 5901003  British Columbia East Kootenay    Elkford                                        2365
# 5901006  British Columbia East Kootenay    Sparwood                                       3440
# ...                                                                                        ...
# 5959806  British Columbia Northern Rockies Fort Nelson 2                                   410
# 5959810  British Columbia Northern Rockies Prophet River 4                                 120
#
# [437 rows x 10 columns]

# %%
df_pivot.to_csv('Mobility_Formatted_Municipalities.csv')

# %%
# listofrows = []
for i in x:
    if x['Characteristic'][i][0] == ' ':
        print(x['Characteristic'][i])
    else:
        print ('failed')
#         listofrows.append(x['Characteristic'][i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6503)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-fb1aeecc06b2> in <module>()
#       1 # listofrows = []
#       2 for i in x:
# ----> 3     if x['Characteristic'][i][0] == ' ':
#       4         print(x['Characteristic'][i])
#       5     else:
#
# /Users/Hea/anaconda/lib/python3.5/site-packages/pandas/core/series.py in __getitem__(self, key)
#     558     def __getitem__(self, key):
#     559         try:
# --> 560             result = self.index.get_value(self, key)
#     561
#     562             if not lib.isscalar(result):
#
# /Users/Hea/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_value(self, series, key)
#    1909         try:
#    1910             return self._engine.get_value(s, k,
# -> 1911                                           tz=getattr(series.dtype, 'tz', None))
#    1912         except KeyError as e1:
#    1913             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3234)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:2931)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3956)()
#
# KeyError: 'Geo_Code'

# %%
with open('mobility_char_list.csv', 'r') as f:
    reader = csv.reader(f)
    characteristics = list(reader)

characteristics
# characteristics[0][0]
# sortbychar(x,characteristics)
# Out:
# [['Total - Mobility status 1 year ago'],
#  ['  Non-movers'],
#  ['  Movers'],
#  ['    Non-migrants'],
#  ['    Migrants'],
#  ['      Internal migrants'],
#  ['        Intraprovincial migrants'],
#  ['        Interprovincial migrants'],
#  ['      External migrants'],
#  ['Total - Mobility status 5 years ago'],
#  ['  Non-movers'],
#  ['  Movers'],
#  ['    Non-migrants'],
#  ['    Migrants'],
#  ['      Internal migrants'],
#  ['        Intraprovincial migrants'],
#  ['        Interprovincial migrants'],
#  ['      External migrants']]

# %%
def sortbychar(df,characteristics):
    df_list = []
    
    for item in characteristics:
        df_temp = df.loc[df['Characteristic'] == item[0]]
        df_temp = df_temp.drop(['Prov_Name', 'GNR','Topic','Characteristic','Note','Male','Female'], axis=1)
        df_temp = df_temp.rename(columns={'Total' : item[0]})
        
        df_list.append(df_temp.reset_index(drop=True))
#         print(len(df_temp),item[0])

    return df_list

# characteristic = ['  Median income ($)']
y = sortbychar(x,characteristics)

# y[0]
y[0]
# Out:
#      Geo_Code           CD_Name         CSD_Name               CSD_type  \
# 0     5901003     East Kootenay          Elkford  District municipality
# 1     5901006     East Kootenay         Sparwood  District municipality
# ..        ...               ...              ...                    ...
# 435   5959806  Northern Rockies    Fort Nelson 2         Indian reserve
# 436   5959810  Northern Rockies  Prophet River 4         Indian reserve
#
#     Total - Mobility status 1 year ago
# 0                                 2495
# 1                                 3625
# ..                                 ...
# 435                                435
# 436                                125
#
# [437 rows x 5 columns]

# %% [raw]
# def parsedata(df,topics,characteristic):
#     df_temp = sortbytopic(df, topics)
#     df_temp = sortbychar(df_temp, characteristic)
#
#     return df_temp
#
# topic = ['Shelter costs','Income of individuals in 2010','Income of households in 2010']
# characteristic = '  Median income ($)'
